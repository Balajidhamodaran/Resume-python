# %%
# Text Variables
Header = '>>I created this CV using Python Matplotlib.Please find the source code in my github link<<'
Name = 'BALAJI DHAMODARAN'
Title = 'Data Science & Analytics'
Contact = 'CONTACT'
Contact1 = 'Kris.dbalaji@gmail.com \n(32) 4 67 67 09 39 \nMol'
SummaryHeader = 'PROFESSIONAL SUMMARY'
SummaryDesc = 'Analytical and detail-oriented professional with a strong foundation in \ndata interpretation, and business strategy. Skilled in leveraging \nanalytical tools and statistical methods to identify trends, generate insights,\nand support data-driven decision-making.'
WorkHeader = 'WORK EXPERIENCE'
WorkOneTitle = 'Role:Techno-Functional Consultant at BNPParibasFortis(2019-2024)'
Project2Title = 'Project:Data Engineering pipeline setup to load historical data layer'
Project2Objective = 'The goal of this project is to design and implement an end-to-end data \nengineering pipeline that ingests, processes, and store historical data from\nmultiple sources to deliver data for analytics and visualization demands.'
Project2Desc = '- Engaged with business users, data scientists to gather requirements\n- Translated business goals into data requirements\n- Documented the requirements as system specifications \n- Analyse and identify relevant source systems\n- Collaborate with source data team to request the requried data\n- Conduct functional validation after the implementation\n- Facilitated demo sessions with the users to get the feedback '
Project1Title = 'Project:Implementation of Data Governance foundation'
Project1Objective = 'The purpose of this project is to establish a foundational Data Governance Framework \nleveraging Ab Initio Metadata Hub as the central platform for metadata \nmanagement and Data Quality enabling compliance with regulatory standards'
Project1Desc = '- Identified Critical Data Elements in the bank \n- Worked with Data Governance experts to define Data Quality measures \n- Prepared the functional specifications doucment \n- Coordinated the collection of data from different business units \n- Validated the Lineage and Data Quality rules once implemented \n- Supported the business team in UAT'
EduHeader = 'EDUCATION'
EduOneTitle = '   Bachelor of Engineering'
CertHeader = 'CERTIFICATION/TRAINING'
Cert1Title = '   Academy Accreditation - Generative AI Fundamentals'
Cert2Title = '   NumPy Essential Training: 1 Foundations of NumPy'
Cert3Title = '   PowerBi Data Analyst Training'
SkillsHeader = 'SKILLS'
SkillsDesc = '- Emotional Intelligence\n- Decision Making\n- Problem Solving\n- Critical Thinking\n- Analytical reasoning'
Software = 'SOFTWARE'
Software1 = '- Azure DevOps\n- HP Octane\n- Bitbucket\n- Jenkins\n- Github\n- Abinitio Datahub\n- Collibra\n- PowerBI\n- MS Office 365\n- Jira\n- Confluence\n- Sharepoint\n- Miro'
Programming = 'PROGRAMMING'
Programming1 = '- SQL\n- Python'
Databases = 'DATABASES'
Databases1 = '- Oracle\n- DB2'
Languages = 'LANGUAGE'
Language1 = 'English - Fluent \nDutch - Conversational'
Github = 'Github'

# Setting style for bar graphs
from matplotlib import pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'Arial'
#plt.rcParams['font.sans-serif'] = ['Helivetica-Light']


fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0.2, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, ymin=0.2, ymax=0.71, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.85, xmin=0.2, xmax=1, color='#ffffff',linewidth=3)
plt.axhline(y=.85, xmin=0.65, xmax=0.02, color='grey',linewidth=1)
plt.axhline(y=.20, xmin=0.65, xmax=0.02, color='grey',linewidth=1)
plt.axhline(y=.12, xmin=0.65, xmax=0.02, color='grey',linewidth=1)
plt.axhline(y=.69, xmin=0.65, xmax=0.02, color='grey',linewidth=1)

# set background color
ax.set_facecolor('white')

# remove axes
plt.axis('off')


# add text
plt.annotate(Header, (.16,.98),  style= 'italic', weight='regular', fontsize=8, color ='grey')
plt.annotate(Name, (.02,.93), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.90), weight='regular', fontsize=12)
plt.annotate(SummaryHeader, (.02,.86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(SummaryDesc, (.02,.76), weight='regular', fontsize=9)
plt.annotate(WorkHeader, (.02,.70), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(WorkOneTitle,(.02,.67), weight='bold', fontsize=9)
plt.annotate(Project2Title, (.02,.64), weight='bold', fontsize=9, alpha=.6)
plt.annotate(Project2Objective, (.02,.59), weight='regular', fontsize=8)
plt.annotate(Project2Desc, (.02,.47), weight='regular', fontsize=8, color='k')
plt.annotate(Project1Title, (.02,.43), weight='bold', fontsize=9, alpha=.6)
plt.annotate(Project1Objective, (.02,.38), weight='regular', fontsize=8)
plt.annotate(Project1Desc, (.02,.27), weight='regular', fontsize=8, color='k')
plt.annotate(EduHeader, (.02,.210), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.180), weight='regular', fontsize=9)
plt.annotate(CertHeader, (.02,.130), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(Cert1Title, (.02,.099), weight='regular', fontsize=9)
plt.annotate(Cert2Title, (.02,.080), weight='regular', fontsize=9)
plt.annotate(Cert3Title, (.02,.060), weight='regular', fontsize=9)
plt.annotate(Contact, (.7,.93), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(Contact1, (.7,.87), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(SkillsHeader, (.7,.82), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsDesc, (.7,.72), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(Software, (.7,.68), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(Software1, (.7,.45), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(Programming, (.7,.40), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(Programming1, (.7,.35), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(Databases, (.7,.30), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(Databases1, (.7,.25), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(Languages, (.7,.20), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(Language1, (.7,.15), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(Github, (.7,.10), weight='bold', fontsize=10, color='#ffffff')
plt.text(0.78, 0.10, 'link', url="https://github.com/Balajidhamodaran/Resume-python/blob/main/Balaji's%20Notebook.ipynb", fontsize=10, color='b')

#add photo
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg
arr_code = mpimg.imread('/Users/balajidhamodaran/Downloads/Balaji_head.png')
imagebox = OffsetImage(arr_code, zoom=0.12)
ab = AnnotationBbox(imagebox, (0.58, 0.91),frameon=False)
ax.add_artist(ab)
plt.savefig('/Users/balajidhamodaran/Downloads/Balaji CV - Data Consultant.pdf', dpi=300, bbox_inches='tight')
plt.show()
